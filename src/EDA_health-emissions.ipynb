# %%
import pandas as pd

# %%
health_risks_df = pd.read_csv("../data/raw/Health_Risk_factors.csv")
health_risks_df.head()
# Out:
#           Country  Prevalence of smoking Male % of adults 2016  \
# 0     Afghanistan                                          NaN
# 1         Albania                                         51.0
# 2         Algeria                                         30.0
# 3  American Samoa                                          NaN
# 4         Andorra                                         38.0
#
#    Prevalence of smoking female % of adults 2016  \
# 0                                            NaN
# 1                                            7.0
# 2                                            1.0
# 3                                            NaN
# 4                                           29.0
#
#    Incidence of tuberculosis  per 100,000 people 2018  \
# 0                                              189.0
# 1                                               18.0
# 2                                               69.0
# 3                                                0.0
# ...

# %%
health_system_df = pd.read_csv("../data/raw/health_system.csv")
health_system_df.head()
# Out:
#           Country  Health expenditure Current % of GDP 2016  \
# 0     Afghanistan                                      10.2
# 1         Albania                                       6.7
# 2         Algeria                                       6.6
# 3  American Samoa                                       NaN
# 4         Andorra                                      10.4
#
#    Health expenditure Public % of current 2016  \
# 0                                          5.1
# 1                                         41.4
# 2                                         67.7
# 3                                          NaN
# 4                                         49.1
#
#    Health expenditure Out of pocket % of current 2016  \
# 0                                               77.4
# 1                                               58.0
# 2                                               30.9
# 3                                                NaN
# ...

# %%
ghg_emission_df = pd.read_csv("../data/raw/greenhouse_gas_emissions.csv")
ghg_emission_df.head()
# Out:
#           Country  \
# 0     Afghanistan
# 1         Albania
# 2         Algeria
# 3  American Samoa
# 4         Andorra
#
#    Total greenhouse gas emissions  thousand metric tons of carbon dioxide equivalent 2012  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               58.8
# 4                                                NaN
#
#    Total greenhouse gas emissions  % change 1990-2012  \
# 0                                               43.5
# 1                                              -19.9
# 2                                               65.8
# 3                                              188.3
# 4                                                NaN
#
#    Methane emissions  thousand metric tons of carbon dioxide equivalent 2012  \
# 0                                                NaN
# ...

# %%
health_risks_df.describe()
# Out:
#        Prevalence of smoking Male % of adults 2016  \
# count                                   143.000000
# mean                                     32.923077
# std                                      13.678438
# min                                       8.000000
# 25%                                      22.500000
# 50%                                      31.000000
# 75%                                      41.500000
# max                                      78.000000
#
#        Prevalence of smoking female % of adults 2016  \
# count                                     145.000000
# mean                                       10.620690
# std                                        10.528446
# min                                         0.000000
# 25%                                         2.000000
# 50%                                         6.000000
# 75%                                        19.000000
# max                                        44.000000
#
# ...

# %%
health_risks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 14 columns):
#  #   Column                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                      --------------  -----
#  0   Country                                                                                                     214 non-null    object
#  1   Prevalence of smoking Male % of adults 2016                                                                 143 non-null    float64
#  2   Prevalence of smoking female % of adults 2016                                                               145 non-null    float64
#  3   Incidence of tuberculosis  per 100,000 people 2018                                                          207 non-null    float64
# ...

# %%
health_risks_df.columns
# Out:
# Index(['Country', 'Prevalence of smoking Male % of adults 2016',
#        'Prevalence of smoking female % of adults 2016',
#        'Incidence of tuberculosis  per 100,000 people 2018',
#        'Prevalence of diabetes  % of population ages 20 to 79 2019',
#        'Incidence of HIV Total per 1,000 uninfected population ages 15-49 2018',
#        'Prevalence of HIV Total % of population ages 15-49 2018',
#        'Prevalence of HIV Women's share of population ages 15+ living with HIV % 2018',
#        'Prevalence of HIV Youth, Male % of population ages 15-24 2018',
#        'Prevalence of HIV Youth, Female % of population ages 15-24 2018',
#        'Antiretroviral therapy coverage  % of people living with HIV 2018',
#        'Cause of death Communicable diseases and maternal, prenatal, and nutrition conditions % of population 2016',
#        'Cause of death Non-communicable diseases % of population 2016',
#        'Cause of death Injuries % of population 2016'],
# ...

# %%
nan_counts = health_risks_df.isna().sum()
print(nan_counts)
# Out:
# Country                                                                                                        0
# Prevalence of smoking Male % of adults 2016                                                                   71
# Prevalence of smoking female % of adults 2016                                                                 69
# Incidence of tuberculosis  per 100,000 people 2018                                                             7
# Prevalence of diabetes  % of population ages 20 to 79 2019                                                     6
# Incidence of HIV Total per 1,000 uninfected population ages 15-49 2018                                        77
# Prevalence of HIV Total % of population ages 15-49 2018                                                       73
# Prevalence of HIV Women's share of population ages 15+ living with HIV % 2018                                 75
# ...

# %%
health_system_df.describe()
# Out:
#        Health expenditure Current % of GDP 2016  \
# count                                186.000000
# mean                                   6.715054
# std                                    2.976537
# min                                    1.700000
# 25%                                    4.500000
# 50%                                    6.200000
# 75%                                    8.375000
# max                                   23.300000
#
#        Health expenditure Public % of current 2016  \
# count                                   186.000000
# mean                                     52.915054
# std                                      21.957736
# min                                       5.100000
# 25%                                      36.825000
# 50%                                      55.850000
# 75%                                      70.600000
# max                                      96.000000
#
#        Health expenditure Out of pocket % of current 2016  \
# ...

# %%
health_system_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 12 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Country                                                               214 non-null    object
#  1   Health expenditure Current % of GDP 2016                              186 non-null    float64
#  2   Health expenditure Public % of current 2016                           186 non-null    float64
#  3   Health expenditure Out of pocket % of current 2016                    186 non-null    float64
#  4   Health expenditure per capita $ 2016                                  136 non-null    float64
#  5   Health expenditure per capita current PPP $ 2016                      110 non-null    float64
# ...

# %%
health_system_df.columns
# Out:
# Index(['Country', 'Health expenditure Current % of GDP 2016',
#        'Health expenditure Public % of current 2016',
#        'Health expenditure Out of pocket % of current 2016',
#        'Health expenditure per capita $ 2016',
#        'Health expenditure per capita current PPP $ 2016',
#        'External health expenditure (% of current health expenditure)   2016',
#        'Health workers Physicians per 1,000 people 2009-18',
#        'Health workers Nurses and midwives per 1,000 people 2009-18',
#        'Specialist surgical workforce  per 100,000 population 2008-18',
#        'Completeness of birth registration  % 2009-18',
#        'Completeness of death registration  % 2008-16'],
#       dtype='object')

# %%
nan_counts = health_system_df.isna().sum()
print(nan_counts)
# Out:
# Country                                                                   0
# Health expenditure Current % of GDP 2016                                 28
# Health expenditure Public % of current 2016                              28
# Health expenditure Out of pocket % of current 2016                       28
# Health expenditure per capita $ 2016                                     78
# Health expenditure per capita current PPP $ 2016                        104
# External health expenditure (% of current health expenditure)   2016     47
# Health workers Physicians per 1,000 people 2009-18                       25
# Health workers Nurses and midwives per 1,000 people 2009-18              25
# Specialist surgical workforce  per 100,000 population 2008-18            39
# Completeness of birth registration  % 2009-18                            51
# Completeness of death registration  % 2008-16                           107
# dtype: int64

# %%
ghg_emission_df.describe()
# Out:
#        Total greenhouse gas emissions  thousand metric tons of carbon dioxide equivalent 2012  \
# count                                          18.000000
# mean                                          381.300000
# std                                           306.474031
# min                                             5.200000
# 25%                                           103.250000
# 50%                                           337.650000
# 75%                                           590.150000
# max                                           959.300000
#
#        Total greenhouse gas emissions  % change 1990-2012  \
# count                                         186.000000
# mean                                           71.663978
# std                                           128.079877
# min                                           -78.000000
# 25%                                            -7.525000
# 50%                                            42.750000
# ...

# %%
ghg_emission_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 13 columns):
#  #   Column                                                                                  Non-Null Count  Dtype
# ---  ------                                                                                  --------------  -----
#  0   Country                                                                                 214 non-null    object
#  1   Total greenhouse gas emissions  thousand metric tons of carbon dioxide equivalent 2012  18 non-null     float64
#  2   Total greenhouse gas emissions  % change 1990-2012                                      186 non-null    float64
#  3   Methane emissions  thousand metric tons of carbon dioxide equivalent 2012               45 non-null     float64
#  4   Methane emissions  % change 1990-2012                                                   200 non-null    float64
# ...

# %%
ghg_emission_df.columns
# Out:
# Index(['Country',
#        'Total greenhouse gas emissions  thousand metric tons of carbon dioxide equivalent 2012',
#        'Total greenhouse gas emissions  % change 1990-2012',
#        'Methane emissions  thousand metric tons of carbon dioxide equivalent 2012',
#        'Methane emissions  % change 1990-2012',
#        'Methane emissions From energy processes % of total 2008',
#        'Methane emissions Agricultural % of total 2008',
#        'Nitrous oxide emissions  thousand metric tons of carbon dioxide equivalent 2012',
#        'Nitrous oxide emissions  % change 1990-2012',
#        'Nitrous oxide emissions From energy processes % of total 2008',
#        'Nitrous oxide emissions Agricultural % of total 2008',
#        'Other greenhouse gas emissions  thousand metric tons of carbon dioxide equivalent 2012',
#        'Other greenhouse gas emissions  % change 1990-2012'],
#       dtype='object')

# %%
nan_counts = ghg_emission_df.isna().sum()
print(nan_counts)
# Out:
# Country                                                                                     0
# Total greenhouse gas emissions  thousand metric tons of carbon dioxide equivalent 2012    196
# Total greenhouse gas emissions  % change 1990-2012                                         28
# Methane emissions  thousand metric tons of carbon dioxide equivalent 2012                 169
# Methane emissions  % change 1990-2012                                                      14
# Methane emissions From energy processes % of total 2008                                    13
# Methane emissions Agricultural % of total 2008                                             13
# Nitrous oxide emissions  thousand metric tons of carbon dioxide equivalent 2012           145
# Nitrous oxide emissions  % change 1990-2012                                                13
# Nitrous oxide emissions From energy processes % of total 2008                              12
# ...
